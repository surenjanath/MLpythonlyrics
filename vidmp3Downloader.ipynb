# %%
# !pip uninstall --target=$nb_path pytube
# Out:
# Usage:
#   pip3 uninstall [options] <package> ...
#   pip3 uninstall [options] -r <requirements file> ...
#
# no such option: --target

# %%
import os, sys
from google.colab import drive
import shutil

drive.flush_and_unmount()
if os.path.isdir('/content/mnt')==False:
  drive.mount('/content/mnt')
  nb_path = '/content/notebooks'
  os.symlink('/content/mnt/My Drive/Colab Notebooks', nb_path)
  sys.path.insert(0, nb_path)  # or append(nb_path)

# Install only once. Tomorrow, you can skip this.
# !pip install --target=$nb_path spacy

# RUN AT BEGINING OF STARTING.
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#       for editing videos
#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$

# path = r'/etc/ImageMagick-6'
# if os.path.isdir(path)==False :
#   ! apt install imagemagick

#   file_path = '/content/mnt/MyDrive/Colab Notebooks/policy.xml'
#   path01 = r'/etc/ImageMagick-6/policy.xml'
#   path02 = r'/etc/ImageMagick-6/policye.xml'
#   try:
#     os.rename(path01,path02)
#   except:
#     print(" Already Renamed. ")
    
# try:
#   shutil.copyfile(file_path, path01)
# except:
#   print('Some Problem happened with moving file. Please Check for file.')
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/mnt

# %%
# !pip install --target=$nb_path spacy

# %%
from pytube import YouTube # downloading videos
from pytube import Playlist
# from moviepy.editor import * # for editing video
import subprocess # splitting videos
import re
import time

# %%
# Libraries to be installed every run

# %%
def download(Link):
    cwdpath = os.getcwd()
    print(f' Your location : {cwdpath}')

    # DOWNLOAD YOUTUBE VIDEOS
    print(' Let\'s download a Video ')
    yt = YouTube(Link)
    title = yt.title
    print(f' Video Name      : {title}')
    desc = yt.description
    lenght = yt.length
    print(f' Length of video : {lenght} seconds')

    video = yt.streams.get_highest_resolution()
    vid_loc = os.path.join(cwdpath,'contents',title.replace(' ',''))
    path = video.download(vid_loc)

    document = {
        'Title'          : title,
        'Description'    : desc,
        'Video_Path'     : path,
        'Video_Folder' : vid_loc
    }
    return document


def split(meta):
  #SPLIT VIDEO
  path  = meta['Video_Path'] 
  print('\n ---------------------------------------------\n')
#check for py  for videosplitter
  splitter = '/content/video-splitter/ffmpeg-split.py'
  if os.path.isfile(splitter) :
    print('\n File is available. Moving along.')
  else:
    # !git clone https://github.com/c0decracker/video-splitter.git
  print('\n ---------------------------------------------\n')

  subprocess.run(['python', splitter ,'-f', path,'-s','59' ])
  os. remove(path) 

def file_retrieve(meta):
  Path  = meta['Video_Folder'] 
  lists = os.listdir(Path)
  x= 0
  paths = []
  for i in lists:
    video_path = os.path.join(Path,i)
    reg = int(re.findall('(-\d-\d*)', i)[0].replace('-',''))
    path_Dict = {
        'Path'      : video_path,
        'Part'      : reg,
        'Vid_title' : meta['Title'],
        'Total_pts' : len(lists)
    }
    print(f' {i} part : {reg}')
    paths.append(path_Dict)
    x+=1
  return paths

  
def MP3_PDownloader(P_Link):
  playlist = P_Link#Playlist(P_Link)
  #prints each video url, which is the same as iterating through playlist.video_urls
  cwd = os.getcwd()
  mp3_folder = os.path.join(cwd,'customSongs')
  video_folder = os.path.join(cwd,'customSongs','VIDEOS')
  try:
    os.mkdir(video_folder)
  except:
    print('Folder : customSongs Found.')
  #  path =  r'/content/customSongs'
  #For saving mp3 files.
  try :
    os.mkdir(os.path.join(mp3_folder,'SONGS'))
  except:
    print(' Folder : Songs Exists already. ')

 
  for url in playlist:

      yt = YouTube(url)

      print('---------------------------------------------')
      try : 
        print(f' Downloading : {yt.title}')
      except:
        continue
      downloadpath = yt.streams.first().download(video_folder)
      print('---------------------------------------------')


      # print(f' Download path : {downloadpath}')
      
      SPLIT_PATH = downloadpath.split('/')
      P = len(SPLIT_PATH)-1
      # print(f' Path = {SPLIT_PATH}')

      

      print(' - Converting mp4 to mp3 - ')
      # /content/customSongs/The Chainsmokers - Dont Let Me Down (Illenium Remix).mp4
      
      try :
        name, ext = SPLIT_PATH[P].split('.')
        if (ext =='mp4'):
          print(f' {name} is converting to mp3 now.')
          #  print('\n---------------------------------------------')
          # print('\n#############################################')
          subprocess.run(['ffmpeg','-i', downloadpath, os.path.join(mp3_folder,'SONGS', f'{name}.mp3')])
          # print(' Disposing of mp4 file. ')
          # os.remove(downloadpath)

      except:
          print('Something wrong... ')
      print('\n---------------------------------------------')
      time.sleep(2.4)
  print(' All work is done')
  
  #Important Zipping musics to download
  print(' Please Wait while I zip for download. \n\n')
  # !zip -r /content/MP3AUDIO.zip /content/customSongs/SONGS
  print('$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$')
  print('\tR E A D Y  F O R  D O W N L O A D !')


# def main():
#     Link = input(' Please Enter YouTube Link : ')
#     meta = download(Link)
#     #https://www.youtube.com/watch?v=d5ZFBbmvlSQ
#     split(meta)
#     file_retrieve(meta)

# %%
pip install ffmpeg
# Out:
# Collecting ffmpeg
#   Downloading https://files.pythonhosted.org/packages/f0/cc/3b7408b8ecf7c1d20ad480c3eaed7619857bf1054b690226e906fdf14258/ffmpeg-1.4.tar.gz
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-cp37-none-any.whl size=6083 sha256=3c7fcc8872fcb6252b5ea78fc96fc76ad809c1e4c8c42edfa90ea6503f228ecd
#   Stored in directory: /root/.cache/pip/wheels/b6/68/c3/a05a35f647ba871e5572b9bbfc0b95fd1c6637a2219f959e7a
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4

# %%
# main() #https://www.youtube.com/watch?v=d5ZFBbmvlSQ

# Link = input(' Please Enter YouTube Link : ')
# meta = download(Link)
# #https://www.youtube.com/watch?v=d5ZFBbmvlSQ
# split(meta)
# Information = file_retrieve(meta)
# for i in Information : 
#   name = i['Vid_title']
#   part = i['Part']
#   print(f' Name : {name} \n Part : {part}')
# Playlist_URL = input('Please ENTER PLAYLIST : ')
LINKS = []
with open('/content/YTLinks.txt','r') as f:
  links = f.readlines()
for link in links:
  LINKS.append(link.replace('\n',''))

#MP3_PDownloader(URLS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7275bc589d3a> in <module>()
#      16 for link in links:
#      17   LINKS.append(link.replace('\n',''))
# ---> 18 len(lLINKS)
#      19 #MP3_PDownloader(URLS)
#
# NameError: name 'lLINKS' is not defined

# %%
URLS = LINKS[1:100]
MP3_PDownloader(URLS)
# Out:
# Folder : customSongs Found.
# ---------------------------------------------
#  Downloading : Faith Hill - "Breathe" (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Faith Hill - Breathe (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Santana - Smooth [ft. Rob Thomas] (Lyrics)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Santana - Smooth [ft Rob Thomas] (Lyrics) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Santana - Maria Maria ft. The Product G&B (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Santana - Maria Maria ft The Product G&B (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : JOE - I WANNA KNOW **(LYRICS ON SCREEN)**
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  JOE - I WANNA KNOW (LYRICS ON SCREEN) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Vertical Horizon - Everything You Want (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Vertical Horizon - Everything You Want (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Destiny's Child - Say My Name (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Destinys Child - Say My Name (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Savage Garden - I Knew I Loved You (Lyrics)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Savage Garden - I Knew I Loved You (Lyrics) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Amazed Lonestar Lyrics
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Amazed Lonestar Lyrics is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Bent - matchbox 20 with lyrics
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Bent - matchbox 20 with lyrics is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Toni Braxton - He Wasn't Man Enough Lyrics HD
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Toni Braxton - He Wasnt Man Enough Lyrics HD is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Creed-Higher with Lyrics
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Creed-Higher with Lyrics is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Aaliyah - Try Again Lyrics
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Aaliyah - Try Again Lyrics is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Destiny's Child - Jumpin’ Jumpin’ (Official Music Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Destinys Child - Jumpin’ Jumpin’ (Official Music Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Sisqo - The Thong Song [LYRICS]
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Sisqo - The Thong Song [LYRICS] is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : 3 doors down - kryptonite (lyrics)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  3 doors down - kryptonite (lyrics) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : P!nk - There You Go (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  P!nk - There You Go (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Madonna - Music [Official Music Video]
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Madonna - Music [Official Music Video] is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Janet Jackson Doesn't Really Matter (Lyrics)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Janet Jackson Doesnt Really Matter (Lyrics) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Christina Aguilera - What A Girl Wants (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Christina Aguilera - What A Girl Wants (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Brian Mcknight - Back at One With Lyrics!
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Brian Mcknight - Back at One With Lyrics! is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : N' Sync   Bye Bye Bye Lyrics
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  N Sync   Bye Bye Bye Lyrics is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Marc Anthony - You Sang To Me (Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Marc Anthony - You Sang To Me (Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Marc Anthony = I Need To Know(lyrics)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Marc Anthony = I Need To Know(lyrics) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Montell Jordan - Get It On Tonite (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Montell Jordan - Get It On Tonite (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Sisqo - Incomplete (Lyrics)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Sisqo - Incomplete (Lyrics) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Macy Gray - I Try (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Macy Gray - I Try (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : *NSYNC - It's Gonna Be Me (Official Music Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  NSYNC - Its Gonna Be Me (Official Music Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Céline Dion - That's The Way It Is (Lyrics)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Céline Dion - Thats The Way It Is (Lyrics) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Nelly - Country Grammar (Hot...) (Official Music Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Nelly - Country Grammar (Hot) (Official Music Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Blaque - Bring It All to Me ft. *NSYNC
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Blaque - Bring It All to Me ft NSYNC is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Backstreet Boys - Show Me The Meaning Of Being Lonely
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Backstreet Boys - Show Me The Meaning Of Being Lonely is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Missy Elliott - Hot Boyz [Remix] (feat. Nas, Eve & Q-Tip)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Missy Elliott - Hot Boyz [Remix] (feat Nas Eve & Q-Tip) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Back Here with lyrics ( BBMak )
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Back Here with lyrics ( BBMak ) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Sonique - It Feels So Good (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Sonique - It Feels So Good (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Nine Days - Absolutely (Story of a Girl) [Official Video]
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Nine Days - Absolutely (Story of a Girl) [Official Video] is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Creed-With Arms Wide Open Lyrics
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Creed-With Arms Wide Open Lyrics is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Enrique Iglesias - Be With You - LYRICS
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Enrique Iglesias - Be With You - LYRICS is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Christina Aguilera - Come On Over (All I Want Is You) (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Christina Aguilera - Come On Over (All I Want Is You) (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Ruff Endz - No More
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Ruff Endz - No More is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Blink 182 - All The Small Things lyrics
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Blink 182 - All The Small Things lyrics is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Faith Hill - "The Way You Love Me" (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Faith Hill - The Way You Love Me (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Christina Aguilera: I Turn To You w/ lyrics on screen
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Christina Aguilera I Turn To You w lyrics on screen is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Third Eye Blind - Never Let You Go (Official Music Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Third Eye Blind - Never Let You Go (Official Music Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : LeAnn Rimes I Need You Lyrics *on screen above & in description below*
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  LeAnn Rimes I Need You Lyrics on screen above & in description below is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Thank God I Found You Lyrics- Mariah Carey ft. 98 Degrees
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Thank God I Found You Lyrics- Mariah Carey ft 98 Degrees is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Jagged Edge - Let's Get Married (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Jagged Edge - Lets Get Married (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Whitney Houston - My Love Is Your Love (Official Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Whitney Houston - My Love Is Your Love (Official Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Smash Mouth - Then The Morning Comes (Official Music Video)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Smash Mouth - Then The Morning Comes (Official Music Video) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
#  Downloading : Eiffel 65 - Blue (Da Ba Dee) (Lyrics)
# ---------------------------------------------
#  - Converting mp4 to mp3 -
#  Eiffel 65 - Blue (Da Ba Dee) (Lyrics) is converting to mp3 now.
#
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
# ---------------------------------------------
#  All work is done
#  Please Wait while I zip for download.
#
#
#   adding: content/customSongs/SONGS/ (stored 0%)
#   adding: content/customSongs/SONGS/Nine Days - Absolutely (Story of a Girl) [Official Video].mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Santana - Smooth [ft Rob Thomas] (Lyrics).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Christina Aguilera - What A Girl Wants (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Sisqo - The Thong Song [LYRICS].mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Savage Garden - I Knew I Loved You (Lyrics).mp3 (deflated 2%)
#   adding: content/customSongs/SONGS/Nelly - Country Grammar (Hot) (Official Music Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Céline Dion - Thats The Way It Is (Lyrics).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/3 doors down - kryptonite (lyrics).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Eiffel 65 - Blue (Da Ba Dee) (Lyrics).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Faith Hill - Breathe (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Jagged Edge - Lets Get Married (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Christina Aguilera - Come On Over (All I Want Is You) (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Enrique Iglesias - Be With You - LYRICS.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/N Sync   Bye Bye Bye Lyrics.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Blaque - Bring It All to Me ft NSYNC.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Amazed Lonestar Lyrics.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/P!nk - There You Go (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Backstreet Boys - Show Me The Meaning Of Being Lonely.mp3 (deflated 3%)
#   adding: content/customSongs/SONGS/Macy Gray - I Try (Official Video).mp3 (deflated 0%)
#   adding: content/customSongs/SONGS/Missy Elliott - Hot Boyz [Remix] (feat Nas Eve & Q-Tip).mp3 (deflated 2%)
#   adding: content/customSongs/SONGS/Faith Hill - The Way You Love Me (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Destinys Child - Say My Name (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Blink 182 - All The Small Things lyrics.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Creed-With Arms Wide Open Lyrics.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Marc Anthony - You Sang To Me (Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Toni Braxton - He Wasnt Man Enough Lyrics HD.mp3 (deflated 3%)
#   adding: content/customSongs/SONGS/Brian Mcknight - Back at One With Lyrics!.mp3 (deflated 2%)
#   adding: content/customSongs/SONGS/Creed-Higher with Lyrics.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Smash Mouth - Then The Morning Comes (Official Music Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Back Here with lyrics ( BBMak ).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Santana - Maria Maria ft The Product G&B (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Marc Anthony = I Need To Know(lyrics).mp3 (deflated 2%)
#   adding: content/customSongs/SONGS/JOE - I WANNA KNOW (LYRICS ON SCREEN).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Ruff Endz - No More.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Third Eye Blind - Never Let You Go (Official Music Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Janet Jackson Doesnt Really Matter (Lyrics).mp3 (deflated 3%)
#   adding: content/customSongs/SONGS/Sisqo - Incomplete (Lyrics).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Bent - matchbox 20 with lyrics.mp3 (deflated 3%)
#   adding: content/customSongs/SONGS/Thank God I Found You Lyrics- Mariah Carey ft 98 Degrees.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Christina Aguilera I Turn To You w lyrics on screen.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Montell Jordan - Get It On Tonite (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/NSYNC - Its Gonna Be Me (Official Music Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Madonna - Music [Official Music Video].mp3 (deflated 2%)
#   adding: content/customSongs/SONGS/Aaliyah - Try Again Lyrics.mp3 (deflated 2%)
#   adding: content/customSongs/SONGS/Vertical Horizon - Everything You Want (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/LeAnn Rimes I Need You Lyrics on screen above & in description below.mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Whitney Houston - My Love Is Your Love (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Sonique - It Feels So Good (Official Video).mp3 (deflated 1%)
#   adding: content/customSongs/SONGS/Destinys Child - Jumpin’ Jumpin’ (Official Music Video).mp3 (deflated 0%)
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# 	R E A D Y  F O R  D O W N L O A D !

# %%
## THIS IS FOR VIDEO EDITING 
## LIBRARY ARE FIXED AND READY TO USED.



count = 1
videoE = VideoFileClip(paths[count], audio=True)
x,y = videoE.size


print(f' x : {x}  y : {y}')

videoE = videoE.margin(top = 110,bottom = 110)

part = TextClip(f' Testing\n\n  {lists[count][:20]}', fontsize = 25, color = 'white') 
part = part.set_position((x/2,40)).set_duration(59) 
videoE = CompositeVideoClip([videoE, part]) 


# part = TextClip(f'{lists[count]}', fontsize = 20, color = 'white') 
# part = part.set_position((x/5,45)).set_duration(59) 
# video = CompositeVideoClip([videoE, part]) 

#video = video.resize( (460,720) )
#video.write_videofile("test.mp4")
video.ipython_display()
#for here to work u need to edit policy after running

# %%
! apt-get install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.

# %%
path =  r'/content/customSongs'

array = os.listdir(path)

# name = reg.find()
print(' - Converting mp4 to mp3 - ')
try : 
  os.mkdir(os.path.join(path,'SONGS'))
except:
  print(' Folder Exists already. ')
for i in array:
  try : 
    name,ext = i.split('.')
    if (ext =='mp4'):
      print(name)
      subprocess.run(['ffmpeg','-i', os.path.join(path,i), os.path.join(path,'SONGS', f'{name}.mp3')])
      os.remove(os.path.join(path,i))

  except:
    print('Something wrong... ')
# Out:
#  - Converting mp4 to mp3 -
#  Folder Exists already.
# I DONT KNOW WHAT THE FUCK IS GOING ON HERE
# Illenium - Needed You (ft Dia Frampton)
# Major Lazer - Be Together feat Wild Belle (Vanic Remix)
# The Chainsmokers - Dont Let Me Down (Illenium Remix)
# Diplo - Revolution (feat Faustix & Imanos and Kai) [SEAN&BOBO Remix]
# PETIT BISCUIT - Sunset Lover

# %%
subprocess.run(['ffmpeg','-i', os.path.join(path,i), os.path.join(path, f'{name}.mp3')])
# Out:
# CompletedProcess(args=['ffmpeg', '-i', '/content/customSongs/SONGS', '/content/customSongs/Daft Punk - Harder Better Faster Stronger (Far Out Remix).mp3'], returncode=1)
